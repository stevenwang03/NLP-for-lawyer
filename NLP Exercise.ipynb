# %% [markdown]
# # NLP for law documents

# %% [markdown]
# The purpose of this exercise is to define a similarity measure and to compute the similarity distances between a given set of phrases representing topics, and sentences that make the judgement.

# %% [markdown]
# ### Reading input files

# %%
# Load library
import pandas as pd
import json
import numpy as np
import re
import os
import sys
import pickle
import os.path
import string
import time
from statistics import mean
from nltk.tokenize import word_tokenize
from gensim.similarities import WmdSimilarity
from gensim import utils
from gensim.models import Doc2Vec
from gensim.models import doc2vec
from gensim.models import Word2Vec
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
stops = set(stopwords.words("french"))
import utils

#read file"
filename="NLP Exercise/judgements.jsonl"

topics={0:"Rupture abusive de la relation de travail",
        1:"Rupture abusive du contrat de travail",
        2:"Rupture brutale de relations commerciales établies",
        3:"Rupture brutale des contrats",
        4:"Indemnité compensatrice de rupture",
        5:"Indemnité compensatrice de congés payés",
        6:"Indemnité compensatrice de préavis"
       }

#pretraitement of topics
listOfTopics=[]
for i in range(0,len(topics)):
    topic_tokens=[w for w in topics[i].lower().split() if not w in stops]
    listOfTopics.append(topic_tokens)

df = pd.read_json (filename, lines=True, encoding='utf-8-sig')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\admin-
# [nltk_data]     local\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\admin-
# [nltk_data]     local\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\admin-
# [nltk_data]     local\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\admin-
# [nltk_data]     local\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Segmentation of judgements by \n\n

# %%
#preprocessing of inputs files"
alljudgements, list_index, list_extractedpharses = utils.preprocessingInputs(df)

# %% [markdown]
# ### Train the model

# %% [markdown]
# Reading decisions files availaible in ftp://echanges.dila.gouv.fr/CAPP/ to use them for the training of the doc2vec model

# %%
repertoryName='CAPP'
utils.ReadTrainingDecisions(repertoryName)

# %%
#load training file
listOfSentences = utils.loadTrainingDecisions()

# %%
#pretraitement of training file
sentencesForTraining = utils.formatTrainingDecisions(listOfSentences)

# %%
#training the model
# /!\ This might take a while
utils.trainingModel(alljudgements, listOfTopics, sentencesForTraining)
# Out:
# Seconds since epoch = 1565881885.0499713
# Epoch # 1 is complete.
# C:\Users\admin-local\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### Compute similarities

# %% [markdown]
# ### Compute first similarity with Word Mover’s Distance (WMD)

# %%
#computethe first  similarity score
model = Doc2Vec.load("doc2vec.model")
scores = utils.computeScoreWmd(alljudgements,listOfTopics, model)
# Out:
# C:\Users\admin-local\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 18.367862224578857  s elapsed.  1001 / 80079
# 19.090914249420166  s elapsed.  2001 / 80079
# 24.221704483032227  s elapsed.  3001 / 80079
# 20.92440676689148  s elapsed.  4001 / 80079
# 19.643333196640015  s elapsed.  5001 / 80079
# 20.712408542633057  s elapsed.  6001 / 80079
# 19.040906190872192  s elapsed.  7001 / 80079
# 18.084809064865112  s elapsed.  8001 / 80079
# 24.152515411376953  s elapsed.  9001 / 80079
# 21.27393364906311  s elapsed.  10001 / 80079
# 18.630186319351196  s elapsed.  11001 / 80079
# 18.090758323669434  s elapsed.  12001 / 80079
# 19.180299520492554  s elapsed.  13001 / 80079
# 18.875241994857788  s elapsed.  14001 / 80079
# 21.69240713119507  s elapsed.  15001 / 80079
# 19.29487109184265  s elapsed.  16001 / 80079
# 20.70745301246643  s elapsed.  17001 / 80079
# 23.760550498962402  s elapsed.  18001 / 80079
# 19.348370790481567  s elapsed.  19001 / 80079
# 18.813805103302002  s elapsed.  20001 / 80079
# 20.284903287887573  s elapsed.  21001 / 80079
# 19.642324447631836  s elapsed.  22001 / 80079
# 19.958874225616455  s elapsed.  23001 / 80079
# 18.818857192993164  s elapsed.  24001 / 80079
# 19.530946493148804  s elapsed.  25001 / 80079
# 19.159350395202637  s elapsed.  26001 / 80079
# 21.56795358657837  s elapsed.  27001 / 80079
# 19.76573085784912  s elapsed.  28001 / 80079
# 18.79679012298584  s elapsed.  29001 / 80079
# 17.809818744659424  s elapsed.  30001 / 80079
# 22.527934551239014  s elapsed.  31001 / 80079
# 19.878334522247314  s elapsed.  32001 / 80079
# 21.046866416931152  s elapsed.  33001 / 80079
# 19.92831039428711  s elapsed.  34001 / 80079
# 19.184730052947998  s elapsed.  35001 / 80079
# 18.560823917388916  s elapsed.  36001 / 80079
# 19.87786841392517  s elapsed.  37001 / 80079
# 18.101869344711304  s elapsed.  38001 / 80079
# 20.08940100669861  s elapsed.  39001 / 80079
# 21.689974546432495  s elapsed.  40001 / 80079
# 18.384366273880005  s elapsed.  41001 / 80079
# 18.466808080673218  s elapsed.  42001 / 80079
# 20.861785650253296  s elapsed.  43001 / 80079
# 17.746243238449097  s elapsed.  44001 / 80079
# 18.24628520011902  s elapsed.  45001 / 80079
# 22.231457948684692  s elapsed.  46001 / 80079
# 18.102363348007202  s elapsed.  47001 / 80079
# 27.80185031890869  s elapsed.  48001 / 80079
# 20.267881631851196  s elapsed.  49001 / 80079
# 19.98681664466858  s elapsed.  50001 / 80079
# 20.867525100708008  s elapsed.  51001 / 80079
# 17.49872088432312  s elapsed.  52001 / 80079
# 18.657346487045288  s elapsed.  53001 / 80079
# 23.08202290534973  s elapsed.  54001 / 80079
# 21.14295196533203  s elapsed.  55001 / 80079
# 19.49839758872986  s elapsed.  56001 / 80079
# 22.546987771987915  s elapsed.  57001 / 80079
# 18.832826137542725  s elapsed.  58001 / 80079
# 18.49628734588623  s elapsed.  59001 / 80079
# 21.341411352157593  s elapsed.  60001 / 80079
# 19.126332998275757  s elapsed.  61001 / 80079
# 21.37604856491089  s elapsed.  62001 / 80079
# 20.110820770263672  s elapsed.  63001 / 80079
# 16.82071042060852  s elapsed.  64001 / 80079
# 18.973329544067383  s elapsed.  65001 / 80079
# 18.15331792831421  s elapsed.  66001 / 80079
# 22.06238055229187  s elapsed.  67001 / 80079
# 21.461838006973267  s elapsed.  68001 / 80079
# 19.14978051185608  s elapsed.  69001 / 80079
# 21.996389150619507  s elapsed.  70001 / 80079
# 24.602954387664795  s elapsed.  71001 / 80079
# 17.03610873222351  s elapsed.  72001 / 80079
# 17.05962824821472  s elapsed.  73001 / 80079
# 20.8593008518219  s elapsed.  74001 / 80079
# 18.857720613479614  s elapsed.  75001 / 80079
# 16.689136266708374  s elapsed.  76001 / 80079
# 18.824714422225952  s elapsed.  77001 / 80079
# 18.331222772598267  s elapsed.  78001 / 80079
# 18.552322387695312  s elapsed.  79001 / 80079
# 18.561841249465942  s elapsed.  80001 / 80079

# %% [markdown]
# ### Building the table for visualization

# %%
score_norm = utils.normalize_scores(scores)

j = 0
ind_sort = np.argsort(score_norm[:,j])
i = -100

#create the table
df = utils.tableResult(list_index,list_extractedpharses,score_norm)
print(list_extractedpharses[ind_sort[i]],listOfTopics[j]," sim score = ", score_norm[ind_sort[i],j], " max_score: ",score_norm[:,j].max())
# Out:
# • 8 882,57 € à titre de dommages et intérêts pour rupture anticipée du contrat de travail à durée déterminée ['rupture', 'abusive', 'relation', 'travail']  sim score =  0.6352747172124967  max_score:  1.0

# %%
#print the dataframe
df

# %% [markdown]
# ### Sorting the table

# %% [markdown]
# Present the table sorted so as to have at the top the most "problematic" cases, that is rows in
# which the best topic is not that distance from the second topic.

# %%
#sort the table and print it
showResult = utils.sortTable(df)

# %%
#print the table
showResult

# %% [markdown]
# ### Compute second similarity with cosine similarity

# %%
#compute the second similarity score
model = Doc2Vec.load("doc2vec.model")

sims=utils.computeScore(alljudgements, listOfTopics, model)
# Forcing similarity values into the interval [0,1]  
sims=(sims>=0)*sims
# Out:
# C:\Users\admin-local\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### Building the table for visualization

# %%
#create the table
dfSecond = utils.tableResult(list_index,list_extractedpharses,sims)

# %% [markdown]
# ### Sorting the table

# %%
#sort the table and print it
showSecondResult = utils.sortTable(dfSecond)

# %%
showSecondResult

# %% [markdown]
# ## Text for Evaluation

# %% [markdown]
# ### Put the new judgements in the evaluation.jsonl file and execute the code below

# %% [markdown]
# find the evaluation.jsonl file in the exercice repertory ; execute the reading and the segmentation box to initialize data and import libraries

# %%
#put the new judgement in evaluation file name evaluation.jsonl

#Reading evaluation.jsonl"
evalFilename="evaluation.jsonl"
df = pd.read_json (evalFilename, lines=True, encoding='utf-8-sig')

#preprocessing of inputs files"
judgements, number_index, visualizepharses = utils.preprocessingInputs(df)

# %% [markdown]
# ### Compute first similarity with Word Mover’s Distance (WMD)

# %%
##load train model
model= Doc2Vec.load("doc2vec.model")

##compute similarity with all topics
scores = utils.computeScoreWmd(judgements, listOfTopics, model)
# Out:
# C:\Users\admin-local\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
#normalize the distance
max_col=utils.loadRefMaxScores()
score_norm = 1./(1.+scores)
for j in range(score_norm.shape[1]):
    max_col.append(score_norm[:,j].max())
    score_norm[:,j]/=max_col[j]

j = 0
ind_sort = np.argsort(score_norm[:,j])
i = -1


##show the result
evalShowResult = utils.tableResult(number_index, visualizepharses, score_norm)
print(visualizepharses[ind_sort[i]],listOfTopics[j]," sim score = ", score_norm[ind_sort[i],j], " max_score: ",score_norm[:,j].max())

#sort the table and print it
evalShowResult = utils.sortTable(evalShowResult)
# Out:
# - 10 000 € à titre de dommages et intérêts pour résistance abusive, ['rupture', 'abusive', 'relation', 'travail']  sim score =  0.6210935026767687  max_score:  0.6210935026767687

# %%
evalShowResult
# Out:
#      line                                               text     sim_a  \
# 16      0                                         INTIMEES :  0.000000
# 232     1                                      30620 BERNIS   0.000000
# 29      0                                           DEBATS :  0.000000
# 222     1                                     81100 CASTRES   0.000000
# 302     2                                          INTIMEE :  0.000000
# 5       0                                                CAL  0.000000
# 311     2                                           DEBATS :  0.000000
# 351     2  - 10 000 € à titre de dommages et intérêts pou...  0.621094
# 403     2  La demande de dommages et intérêts pour résist...  0.535329
# 209     1                                    CHAMBRE CIVILE   0.516884
# 217     1                                     W... W... ...   0.276571
# 227     1                               30320 SAINT GERVAZY   0.356966
# 397     2          La compensation entre les deux créances :  0.467219
# 213     1                                  R. G : 13/ 01459   0.343897
# 296     2                          CHAMBRE CIVILE-1o SECTION  0.457439
# 27      0                                         GREFFIER :  0.384238
# 309     2                                         GREFFIER :  0.384238
# 241     1                                        GREFFIER :   0.384238
# 134     0  3.1  Sur la force probante du contrat de cauti...  0.383822
# 441     6                                Infirme le jugement  0.485072
# 92      0                              En toutes hypothèses,  0.299488
# 433     4                   la terre tourne autour du soleil  0.293228
# 226     1                               Monsieur Jaouad Y...  0.403247
# 288     2                               R.G : No RG 17/01992  0.377320
# 60      0   déclaré le jugement commun et opposable à Mme...  0.437734
# 71      0                        Mme  J... est décédée le  .  0.348959
# 148     0   Caisse Régionale de Crédit Agricole Mutuel du...  0.412117
# 177     0              4. Sur la responsabilité de la banque  0.495307
# 210     1                                    1ère Chambre A   0.465227
# 14      0                                 Monsieur E... J...  0.447932
# ..    ...                                                ...       ...
# 440     6                          PAR CES MOTIFS , LA COUR,  0.530692
# 295     2                              COUR D'APPEL DE REIMS  0.401834
# 9       0                              COUR D'APPEL DE REIMS  0.401834
# 101     0   la déclarer bien fondée en ses demandes, et y...  0.471140
# 387     2  La demande formée à hauteur d'appel par la SEL...  0.428918
# 439     5                 Condamne l'URSSAF PACA aux dépens.  0.361290
# 214     1              TRIBUNAL DE GRANDE INSTANCE DE NIMES   0.512131
# 331     2  Par déclaration reçue le 20 juillet 2017, la S...  0.444457
# 208     1                             COUR D'APPEL DE NÎMES   0.435758
# 257     1  REFORMER le jugement rendu le 7 février 2013 p...  0.474278
# 409     2                        La décision sera confirmée.  0.422600
# 412     2                        La décision sera confirmée.  0.422600
# 188     0             4.2 Sur le défaut de prise de garantie  0.507360
# 399     2             Les demandes de dommages et intérêts :  0.540014
# 419     2  et en ce qu'il a condamné la SELAS Pharmacie C...  0.408116
# 348     2  - de condamner la SELAS Pharmacie Charon à pay...  0.407362
# 329     2  - que la pharmacie, qui arguait d'une remise q...  0.406428
# 353     2  - de condamner la SELAS Pharmacie Charon aux e...  0.438928
# 73      0   infirmer le jugement dont appel dans la mesur...  0.454187
# 140     0  L'article L.3412 du code de la consommation, d...  0.466076
# 448     6   1 500 € de dommages et intérêts en réparation...  0.401690
# 318     2  Dans le cadre de leurs activités, la SELAS Pha...  0.396013
# 424     2  Condamne la SAS Sandoz à payer à la SELAS Phar...  0.421186
# 401     2  La demande de dommages et intérêts pour préjud...  0.442677
# 430     2  Condamne la SELAS Pharmacie Charon aux dépens ...  0.424757
# 63      0                    ordonné l'exécution provisoire.  0.475282
# 8       0                                      Maître HYONNE  0.402640
# 366     2  L'appelante soutient que pour l'année 2012, sa...  0.414372
# 225     1                                         INTIMÉS :   0.420052
# 324     2  - que les relations entre les parties étaient ...  0.364873
#
#         sim_b     sim_c     sim_d     sim_e     sim_f     sim_g
# 16   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 232  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 29   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 222  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 302  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 311  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# 225  0.320104  0.186831  0.628698  0.289827  0.048549  0.047321
# 324  0.274736  0.179106  0.584596  0.227807  0.038823  0.038020
#
# [460 rows x 9 columns]

# %% [markdown]
# ### Compute second similarity with cosine similarity

# %%
#compute the second similarity score 
sims2 = utils.computeScore(judgements,listOfTopics,model)
# Forcing similarity values into the interval [0,1]  
sims2=(sims2>=0)*sims2

# %%
##show the result
evalShowResult2 = utils.tableResult(number_index, visualizepharses, sims2 )
#sort the table and print it
evalShowResult2 = utils.sortTable(evalShowResult2)

# %%
evalShowResult2
# Out:
#      line                                               text     sim_a  \
# 16      0                                         INTIMEES :  0.000000
# 29      0                                           DEBATS :  0.000000
# 232     1                                      30620 BERNIS   0.000000
# 5       0                                                CAL  0.000000
# 302     2                                          INTIMEE :  0.000000
# 311     2                                           DEBATS :  0.000000
# 222     1                                     81100 CASTRES   0.000000
# 399     2             Les demandes de dommages et intérêts :  0.105961
# 18      0        Non comparant, n'ayant pas constitué avocat  0.152776
# 52      0   débouté Mme J... de sa demande en responsabil...  0.191868
# 437     5  Déclare l'assignation en redressement judiciai...  0.147869
# 373     2  La règle est donc la commande écrite et si la ...  0.086535
# 192     0            5. Sur la demande de délais de paiement  0.132812
# 263     1                      refroidissement du véhicule,  -0.000000
# 205     0  CONDAMNE M. E... J... à payer à la SA BNP Pari...  0.082909
# 396     2  Elle sera donc condamnée à payer à la SELAS Ph...  0.070546
# 172     0  Au regard de tout ce qui précède, et dans la m...  0.124773
# 407     2  Elle ne la démontre pas, de sorte que sa deman...  0.079690
# 435     5  La cour, statuant publiquement, par mise à dis...  0.093974
# 281     1                      Confirme le jugement déféré.   0.070105
# 278     1                                          LA COUR,   0.007002
# 137     0  Dès lors, c'est à juste titre que le tribunal ...  0.012029
# 200     0  Enfin, il n'est pas inéquitable de faire appli...  0.129944
# 448     6   1 500 € de dommages et intérêts en réparation...  0.028915
# 170     0  Dès lors, au regard de l'ensemble de ces éléme...  0.083002
# 371     2  Il conditionne chaque commande de prestations ...  0.061191
# 191     0  Le jugement mérite donc confirmation en ce qu'...  0.033184
# 273     1  Attendu que la W... W... ... a vendu le véhicu...  0.116404
# 40      0  La cour d'appel de Reims a rendu son arrêt le ...  0.089047
# 322     2  Par décision du 20 juin 2017, le tribunal a co...  0.109639
# ..    ...                                                ...       ...
# 26      0                Madame Catherine LEFORT, conseiller  0.061352
# 83      0   à tout le moins, condamner  la société BNP Pa...  0.155855
# 85      0   subsidiairement, dire et juger que l'engageme...  0.051082
# 458     7               DÉBOUTE Xxxx de toutes ses demandes.  0.117531
# 182     0  La caution avertie doit, quant à elle, prouver...  0.034635
# 133     0                 3. Sur le contrat de cautionnement  0.131023
# 271     1  La mise en état a été clôturée par ordonnance ... -0.000000
# 382     2  * le fait qu'elle achetait des spécialités gén...  0.081176
# 247     1  Arrêt par défaut, prononcé et signé par M. Ser...  0.099562
# 59      0   rejeté la demande  délais et report présentée...  0.026191
# 297     2                         ARRÊT DU 04 SEPTEMBRE 2018  0.140081
# 316     2  La SAS Sandoz exerce une activité commerciale ... -0.000000
# 265     1  CONDAMNER solidairement la W... W... ... et Mo...  0.069594
# 271 -0.000000  0.014045  0.086785 -0.000000 -0.000000 -0.000000
# 382  0.126997  0.136757  0.152083  0.208081  0.282127  0.188481
# 247  0.025148  0.010374  0.002425 -0.000000 -0.000000  0.012470
# 59   0.045785  0.108325  0.190443  0.103965  0.115687  0.074371
# 297  0.217128  0.084692  0.133185  0.043183  0.075924  0.019058
# 316  0.001957  0.182817  0.081684  0.016165  0.105276  0.084724
# 265  0.106557  0.080349  0.047528  0.189628  0.213272  0.292447
# 139  0.241292  0.092818  0.113909  0.158763  0.154675  0.160752
# 203  0.053918  0.163842  0.054531 -0.000000  0.078524  0.015620
# 351  0.425177  0.154558  0.302376  0.260527  0.230990  0.196665
# 318  0.153561  0.129848  0.241902  0.028314  0.092292  0.095046
# 24   0.003111  0.019798 -0.000000  0.042124  0.013638  0.062687
# 306  0.003111  0.019798 -0.000000  0.042124  0.013638  0.062687
# 261  0.102187  0.097484  0.069650  0.117664  0.150785  0.244054
# 9   -0.000000  0.116494  0.022111 -0.000000 -0.000000 -0.000000
# 295 -0.000000  0.116494  0.022111 -0.000000 -0.000000 -0.000000
# 432  0.301170  0.098327  0.178354  0.193687  0.115074  0.195337
# 282  0.115029  0.115306  0.082424  0.185080  0.196624  0.299420
# 447  0.238256  0.077073  0.133145  0.571597  0.746257  0.641761
# 299  0.070355  0.176155  0.036517 -0.000000  0.044352 -0.000000
# 221 -0.000000 -0.000000 -0.000000 -0.000000  0.008280  0.117695
# 13   0.067133  0.180196  0.063617 -0.000000  0.043988 -0.000000
# 138  0.248030  0.134670  0.107340  0.134763  0.118401  0.086544
# 330  0.189834  0.320799  0.195732  0.078715  0.061819  0.086956
#
# [460 rows x 9 columns]

# %% [markdown]
# ### Methodology to identify topics at word level

# %% [raw]
# We used the word moving distance to measure similarities between extracted phrases and decisions.
#
#
# Intuitively, WMD views phrases as “matter” distributions in the word embedding space. The masses are equal to the words normalized frequencies and they are located at the word embeddings positions. To compute the distance between two phrases, WMD seeks the minimal effort to move mass from the first phrase distribution to the second distribution. The shorter distance is the overall distance travelled by "matter" particles, the smaller the distance is, the less effort will be in WMD paradigm. Concretely, WMD solves an optimization problem otherwise known as the optimal transportation problem. It computes a pairing matrix, which is a matrix indicating the mass to travel along for each pair of locations between the two distributions. The distance between the two phrases is given by the minimal transportation cost.
#
# The pairing matrix capture a maximum of semantics. Indeed, each value of the pairing matrix gives a lower boundary on the corresponding pair of words frequencies. Thus, high values in the pairing matrix indicate pairs of highly frequent words, and in first approximation, important words. Moreover, these high values have to be assigned to short travelling distances, for transportation to be cost-effective. Recalling that these distances are computed in the word embedding space, it means that short distance indicates semantic relatedness between words. In other words, high values in the pairing matrix likely indicates pairs of both important and semantically related words between the two phrases compared. It is, therefore, a suitable tool to access words level information.
#
#
# Gensim WMD class, unfortunately, doesn’t provide the pairing matrix. Thus, from a practical point o view, one can either modify Gensim source code to retrieve it, use WMD from an NLP library which returns the pairing matrix or turn directly to optimal transport libraries like POT in python.

# %% [markdown]
# ### Improvements

# %% [raw]
# To improve the accuracy of the results, some improvements can be made:
#
# -Additional data cleaning
#         -identification and removal of irrelevant extracted pharses
#         -identification and removal of meaningless words
#
# -refine the model parameters
